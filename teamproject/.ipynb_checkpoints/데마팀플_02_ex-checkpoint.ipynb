# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False
import numpy as np
import seaborn as sns
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

df = pd.read_excel('5_패스생성정보.xlsx')                 # 파일 읽어옴
df.columns = ['패스명', '패스메모', 'road', '등록일시']      # 경로 split하기 위해서 column이름 바꿈
for i in range (length(road_list)):
    road_list = df.road.str.split(' ->').str[0].tolist()   # ' ->'로 split 후 리스트에 넣음


df = pd.DataFrame(road_list)      # 리스트를 dataframe형식으로 바꿈
                              # 같은것끼리 카운트
# print(df)
df = df.dropna(axis=0)
print(df)
df = df.value_counts()   
df
# df.to_excel('exam.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 13
#      11 df = pd.read_excel('5_패스생성정보.xlsx')                 # 파일 읽어옴
#      12 df.columns = ['패스명', '패스메모', 'road', '등록일시']      # 경로 split하기 위해서 column이름 바꿈
# ---> 13 for i in range (length(road_list)):
#      14     road_list = df.road.str.split(' ->').str[0].tolist()   # ' ->'로 split 후 리스트에 넣음
#      17 df = pd.DataFrame(road_list)      # 리스트를 dataframe형식으로 바꿈
#
# NameError: name 'length' is not defined

# %%
plt.figure(figsize=(25, 10))

p = df[df>=10]
# plt.style.use('t')
plt.title('방문', fontsize=30)
p.plot.bar(width=0.5, fontsize=15)
# Out:
# <AxesSubplot: title={'center': '방문'}, xlabel='0'>

# %%
plt.figure(figsize=(20, 20))
p = df[df>=25]
p.plot.pie(fontsize=10, startangle = 45, counterclock = True)
# Out:
# <AxesSubplot: >

# %%
from PIL import Image
from wordcloud import STOPWORDS
stopword=set(STOPWORDS)
stopword.add('dtype')
stopword.add('int64')
stopword.add('Length')
stopword.add('said')


text = temp_list
smart_incheon= np.array(Image.open('./스마트관광도시지도.png'))

# %%
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt
# from collections import Counter
# import math


# Counter(df)
# p = df[df>=10]
# temp_list = str(df)
# print(temp_list)

# wordcloud = WordCloud(font_path='~/Library/Fonts/Arial Unicode.ttf',background_color='white').generate(temp_list)
# plt.figure(figsize=(20,20)) #이미지 사이즈 지정
# plt.imshow(wordcloud, interpolation='bilinear') #이미지의 부드럽기 정도
# plt.axis('off') #x y 축 숫자 제거
#plt.show()

# %%
wc = WordCloud(background_color='white',max_words=2000,mask=smart_incheon, stopwords= stopword)
wc = wc.generate(text)

plt.figure(figsize=(12,12))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(smart_incheon,cmap=plt.cm.gray, interpolation='bilinear') 
# alice는 그냥 그리고, mask 이미지 읽은.부분에서 넘파이 어레이로 0101로 읽음
# mask로 그림을 그림
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
