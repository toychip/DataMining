# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False
import numpy as np
import seaborn as sns
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

df = pd.read_excel('6_이용자정보.xlsx')

# grouped = df.groupby(['연령대'])
# # print(grouped)

df.columns = ['고유번호', '가입일', '회원구분(가입채널)', '성별', 'age','국적','hobb']
df

# 관심사 안에 맛집탐방이 있으면
# Out:
#         고유번호                  가입일 회원구분(가입채널)  성별  age  국적  \
# 0      25033  2022-10-05 15:43:07      KAKAO  여자  30대  KR
# 1      25032  2022-10-05 15:27:01      KAKAO  남자  50대  KR
# 2      25031  2022-10-05 15:06:40      NAVER  여자  20대  KR
# 3      25030  2022-10-05 14:55:54      KAKAO  여자  40대  KR
# 4      25029  2022-10-05 14:40:54     GOOGLE  남자  40대  KR
# ...      ...                  ...        ...  ..  ...  ..
# 21459    308  2021-03-29 10:58:44        APP  여자  20대  KR
# 21460    307  2021-03-29 10:58:36        APP  여자  20대  KR
# 21461    306  2021-03-29 10:58:21        APP  여자  20대  KR
# 21462    305  2021-03-27 13:21:54        APP  여자  20대  KR
# 21463    304  2021-03-27 13:21:34        APP  여자  20대  KR
#
#                                   hobb
# 0      액티비티,맛집탐방,관광명소,역사/문화,인생사진,자연/힐링
# 1                           맛집탐방,자연/힐링
# 2            액티비티,맛집탐방,관광명소,역사/문화,인생사진
# 3      액티비티,맛집탐방,관광명소,역사/문화,인생사진,자연/힐링
# 4      액티비티,맛집탐방,관광명소,역사/문화,인생사진,자연/힐링
# ...

# %%
df.isnull()
# Out:
#         고유번호    가입일  회원구분(가입채널)     성별    age     국적   hobb
# 0      False  False       False  False  False  False  False
# 1      False  False       False  False  False  False  False
# 2      False  False       False  False  False  False  False
# 3      False  False       False  False  False  False  False
# 4      False  False       False  False  False  False  False
# ...      ...    ...         ...    ...    ...    ...    ...
# 21459  False  False       False  False  False  False  False
# 21460  False  False       False  False  False  False  False
# 21461  False  False       False  False  False  False  False
# 21462  False  False       False  False  False  False  False
# 21463  False  False       False  False  False  False  False
#
# [21464 rows x 7 columns]

# %%
df[df['age'].str.contains('20대')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 df[df['age'].str.contains('20대')]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3795, in DataFrame.__getitem__(self, key)
#    3792     return self.where(key)
#    3794 # Do we have a (boolean) 1d indexer?
# -> 3795 if com.is_bool_indexer(key):
#    3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %% [markdown]
# ## 20대

# %%
twenties = (df['age'] == '20대')
favtw = df.loc[twenties, ['hobb']]

# .를 끊어서 각자 저장
favtw['hobb2'] = favtw.hobb.str.split(',').str[0] 
favtw['hobb3'] = favtw.hobb.str.split(',').str[1]
favtw['hobb4'] = favtw.hobb.str.split(',').str[2]
favtw['hobb5'] = favtw.hobb.str.split(',').str[3]
favtw['hobb6'] = favtw.hobb.str.split(',').str[4]
favtw['hobb7'] = favtw.hobb.str.split(',').str[5]

# hobb를 제외한 
favtw = favtw.loc[:, 'hobb2':'hobb7']
favtw.fillna(0)

temp2_20 = favtw['hobb2'].value_counts()
temp3_20 = favtw['hobb3'].value_counts()
temp4_20  = favtw['hobb4'].value_counts()
temp5_20  = favtw['hobb5'].value_counts()
temp6_20  = favtw['hobb6'].value_counts()
temp7_20  = favtw['hobb7'].value_counts()

# %% [markdown]
# ## 30대

# %%
thirties = (df['age'] == '30대')
favth = df.loc[thirties, ['age', 'hobb']]

# .를 끊어서 각자 저장
favth['hobb2'] = favth.hobb.str.split(',').str[0] 
favth['hobb3'] = favth.hobb.str.split(',').str[1]
favth['hobb4'] = favth.hobb.str.split(',').str[2]
favth['hobb5'] = favth.hobb.str.split(',').str[3]
favth['hobb6'] = favth.hobb.str.split(',').str[4]
favth['hobb7'] = favth.hobb.str.split(',').str[5]

# hobb를 제외한 
favth = favth.loc[:, 'hobb2':'hobb7']
favth.fillna(0)

temp2_30  = favth['hobb2'].value_counts()
temp3_30 = favth['hobb3'].value_counts()
temp4_30 = favth['hobb4'].value_counts()
temp5_30 = favth['hobb5'].value_counts()
temp6_30 = favth['hobb6'].value_counts()
temp7_30 = favth['hobb7'].value_counts()

# %% [markdown]
# ## 40대

# %%
forties = (df['age'] == '40대')
favfo = df.loc[forties, ['age', 'hobb']]

# .를 끊어서 각자 저장
favfo['hobb2'] = favfo.hobb.str.split(',').str[0] 
favfo['hobb3'] = favfo.hobb.str.split(',').str[1]
favfo['hobb4'] = favfo.hobb.str.split(',').str[2]
favfo['hobb5'] = favfo.hobb.str.split(',').str[3]
favfo['hobb6'] = favfo.hobb.str.split(',').str[4]
favfo['hobb7'] = favfo.hobb.str.split(',').str[5]

# hobb를 제외한 
favfo = favfo.loc[:, 'hobb2':'hobb7']
favfo.fillna(0)

temp2_40 = favfo['hobb2'].value_counts()
temp3_40 = favfo['hobb3'].value_counts()
temp4_40 = favfo['hobb4'].value_counts()
temp5_40 = favfo['hobb5'].value_counts()
temp6_40 = favfo['hobb6'].value_counts()
temp7_40 = favfo['hobb7'].value_counts()

# %% [markdown]
# ## 50대

# %%
fifties = (df['age'] == '50대')
favfi = df.loc[fifties, ['age', 'hobb']]

# .를 끊어서 각자 저장
favfi['hobb2'] = favfi.hobb.str.split(',').str[0] 
favfi['hobb3'] = favfi.hobb.str.split(',').str[1]
favfi['hobb4'] = favfi.hobb.str.split(',').str[2]
favfi['hobb5'] = favfi.hobb.str.split(',').str[3]
favfi['hobb6'] = favfi.hobb.str.split(',').str[4]
favfi['hobb7'] = favfi.hobb.str.split(',').str[5]

# hobb를 제외한 
favfi = favfi.loc[:, 'hobb2':'hobb7']
favfi.fillna(0)

temp2_50 = favfi['hobb2'].value_counts()
temp3_50 = favfi['hobb3'].value_counts()
temp4_50 = favfi['hobb4'].value_counts()
temp5_50 = favfi['hobb5'].value_counts()
temp6_50 = favfi['hobb6'].value_counts()
temp7_50 = favfi['hobb7'].value_counts()

# %% [markdown]
# ## 60대

# %%
sixties = (df['age'] == '60대 이상')
favsi = df.loc[sixties, ['hobb']]

# .를 끊어서 각자 저장
favsi['hobb2'] = favsi.hobb.str.split(',').str[0] 
favsi['hobb3'] = favsi.hobb.str.split(',').str[1]
favsi['hobb4'] = favsi.hobb.str.split(',').str[2]
favsi['hobb5'] = favsi.hobb.str.split(',').str[3]
favsi['hobb6'] = favsi.hobb.str.split(',').str[4]
favsi['hobb7'] = favsi.hobb.str.split(',').str[5]

# hobb를 제외한 
favsi = favsi.loc[:, 'hobb2':'hobb7']
favsi.fillna(0)

temp2_60 = favsi['hobb2'].value_counts()
temp3_60 = favsi['hobb3'].value_counts()
temp4_60 = favsi['hobb4'].value_counts()
temp5_60 = favsi['hobb5'].value_counts()
temp6_60 = favsi['hobb6'].value_counts()
temp7_60 = favsi['hobb7'].value_counts()

# %%
# 그래프 데이터 정리
values20 = [activity20, findrest20, picture20, natuheal20, attraction20, hiscul20]
values30 = [activity30, findrest30, picture30, natuheal30, attraction30, hiscul30]
values40 = [activity40, findrest40, picture40, natuheal40, attraction40, hiscul40]
values50 = [activity50, findrest50, picture50, natuheal50, attraction50, hiscul50]
values60 = [activity60, findrest60, picture60, natuheal60, attraction60, hiscul60]
# values20
# values30
# values40
# values50
# values60

# %% [markdown]
# ## 20대 원 그래프

# %%
labels = ["액티비티", "맛집탐방", "인생사진", "자연/힐링", "관광명소", "역사/문화"]
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.07] * 6
plt.pie(values20, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
plt.legend(loc = (1, 0.7), title = '20대 관심사')
plt.show()

# %% [markdown]
# ## 30대 원 그래프

# %%
labels = ["액티비티", "맛집탐방", "인생사진", "자연/힐링", "관광명소", "역사/문화"]
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.07] * 6
plt.pie(values30, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
plt.legend(loc = (1, 0.7), title = '30대 관심사')
plt.show()

# %% [markdown]
# ## 40대 원 그래프

# %%
labels = ["액티비티", "맛집탐방", "인생사진", "자연/힐링", "관광명소", "역사/문화"]
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.07] * 6
plt.pie(values40, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
plt.legend(loc = (1, 0.7), title = '40대 관심사')
plt.show()

# %% [markdown]
# ## 50대 원 그래프

# %%
labels = ["액티비티", "맛집탐방", "인생사진", "자연/힐링", "관광명소", "역사/문화"]
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.07] * 6
plt.pie(values50, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
plt.legend(loc = (1, 0.7), title = '50대 관심사')
plt.show()

# %% [markdown]
# ## 60대 이상 원 그래프

# %%
labels = ["액티비티", "맛집탐방", "인생사진", "자연/힐링", "관광명소", "역사/문화"]
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.07] * 6
plt.pie(values60, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
plt.legend(loc = (1, 0.7), title = '60대 관심사')
plt.show()

# %%
# plt.bar(labels, values20, label = '20대 관심사')
# plt.bar(labels, values30, bottom=values20, label = '30대 관심사')
# plt.bar(labels, values40, bottom=values20 + values, label = '30대 관심사')
# plt.xticks(rotation=20)
# plt.legend()
bar_index = np.arange(6)
w = 0.17
plt.bar(bar_index - w * 2, values20, width = 0.2, label = '20대')
plt.bar(bar_index - w, values30, width = 0.2, label = '30대')
plt.bar(bar_index , values40, width = 0.2, label = '40대')
plt.bar(bar_index + w, values50, width = 0.2, label = '50대')
plt.bar(bar_index + w * 2, values60, width = 0.2, label = '60대이상')
plt.legend()
plt.xticks(bar_index, labels)
# Out:
# ([<matplotlib.axis.XTick at 0x290420a60>,
# ...
#  [Text(0, 0, '액티비티'),
#   Text(1, 0, '맛집탐방'),
#   Text(2, 0, '인생사진'),
#   Text(3, 0, '자연/힐링'),
#   Text(4, 0, '관광명소'),
#   Text(5, 0, '역사/문화')])

# %%
print("20대 관심사")
activity20 = temp2_20[0]
print("20대 액티비티: ", activity20)
findrest20 = temp2_20[1] + temp3_20[0]
print("20대 맛집탐방: ",findrest20)
picture20 = temp2_20[2] + temp3_20[1] + temp4_20[0]
print("20대 인생사진: ",picture20)
natuheal20 = temp2_20[3] + temp3_20[2] + temp4_20[1] + temp5_20[0]
print("20대 자연/힐링: ",natuheal20)
attraction20 = temp2_20[4] + temp3_20[3] + temp4_20[2] + temp5_20[1] + temp6_20[0]
print("20대 관광명소: ",attraction20)
hiscul20 = temp2_20[5] + temp3_20[4] + temp4_20[3] + temp5_20[2] + temp6_20[1]
print("20대 역사/문화: ",hiscul20)
print()
print("30대 관심사")
activity30 = temp2_30[0]
print("30대 액티비티: ", activity30)
findrest30 = temp2_30[1] + temp3_30[0]
print("30대 맛집탐방: ",findrest30)
picture30 = temp2_30[2] + temp3_30[1] + temp4_30[0]
print("30대 인생사진: ",picture30)
natuheal30 = temp2_30[3] + temp3_30[2] + temp4_30[1] + temp5_30[0]
print("30대 자연/힐링: ",natuheal30)
attraction30 = temp2_30[4] + temp3_30[3] + temp4_30[2] + temp5_30[1] + temp6_30[0]
print("30대 관광명소: ",attraction30)
hiscul30 = temp2_30[5] + temp3_30[4] + temp4_30[3] + temp5_30[2] + temp6_30[1]
print("30대 역사/문화: ",hiscul30)
print()
print("40대 관심사")
activity40 = temp2_40[0]
print("40대 액티비티: ", activity40)
findrest40 = temp2_40[1] + temp3_40[0]
print("40대 맛집탐방: ",findrest40)
picture40 = temp2_40[2] + temp3_40[1] + temp4_40[0]
print("40대 인생사진: ",picture40)
natuheal40 = temp2_40[3] + temp3_40[2] + temp4_40[1] + temp5_40[0]
print("40대 자연/힐링: ",natuheal40)
attraction40 = temp2_40[4] + temp3_40[3] + temp4_40[2] + temp5_40[1] + temp6_40[0]
print("40대 관광명소: ",attraction40)
hiscul40 = temp2_40[5] + temp3_40[4] + temp4_40[3] + temp5_40[2] + temp6_40[1]
print("40대 역사/문화: ",hiscul40)
print()
print("50대 관심사")
activity50 = temp2_50[0]
print("50대 액티비티: ", activity50)
findrest50 = temp2_50[1] + temp3_50[0]
print("50대 맛집탐방: ",findrest50)
picture50 = temp2_50[2] + temp3_50[1] + temp4_50[0]
print("50대 인생사진: ",picture50)
natuheal50 = temp2_50[3] + temp3_50[2] + temp4_50[1] + temp5_50[0]
print("50대 자연/힐링: ",natuheal50)
attraction50 = temp2_50[4] + temp3_50[3] + temp4_50[2] + temp5_50[1] + temp6_50[0]
print("50대 관광명소: ",attraction50)
hiscul50 = temp2_50[5] + temp3_50[4] + temp4_50[3] + temp5_50[2] + temp6_50[1]
print("50대 역사/문화: ",hiscul50)
print()
print("60대 이상 관심사")
activity60 = temp2_60[0]
print("60대 이상 액티비티: ", activity60)
findrest60 = temp2_60[1] + temp3_60[0]
print("60대 이상 맛집탐방: ",findrest60)
picture60 = temp2_60[2] + temp3_60[1] + temp4_60[0]
print("60대 이상 인생사진: ",picture60)
natuheal60 = temp2_60[3] + temp3_60[2] + temp4_60[1] + temp5_60[0]
print("60대 이상 자연/힐링: ",natuheal60)
attraction60 = temp2_60[4] + temp3_60[3] + temp4_60[2] + temp5_60[1] + temp6_60[0]
print("60대 이상 관광명소: ",attraction60)
hiscul60 = temp2_60[5] + temp3_60[4] + temp4_60[3] + temp5_60[2] + temp6_60[1]
print("60대 이상 역사/문화: ",hiscul60)
# Out:
# 20대 관심사
# 20대 액티비티:  2857
# 20대 맛집탐방:  3343
# 20대 인생사진:  2708
# 20대 자연/힐링:  1940
# 20대 관광명소:  2199
# 20대 역사/문화:  1268
#
# 30대 관심사
# 30대 액티비티:  3550
# 30대 맛집탐방:  3862
# 30대 인생사진:  2902
# 30대 자연/힐링:  2172
# 30대 관광명소:  2258
# 30대 역사/문화:  1387
#
# 40대 관심사
# 40대 액티비티:  3654
# 40대 맛집탐방:  3999
# 40대 인생사진:  2312
# 40대 자연/힐링:  2295
# 40대 관광명소:  2409
# 40대 역사/문화:  1480
#
# 50대 관심사
# 50대 액티비티:  1535
# 50대 맛집탐방:  1596
# 50대 인생사진:  818
# 50대 자연/힐링:  939
# 50대 관광명소:  943
# 50대 역사/문화:  606
#
# 60대 이상 관심사
# 60대 이상 액티비티:  582
# 60대 이상 맛집탐방:  657
# 60대 이상 인생사진:  311
# 60대 이상 자연/힐링:  305
# 60대 이상 관광명소:  334
# 60대 이상 역사/문화:  233

# %%
fig, axs = plt.subplots(3, 2, figsize = (10, 10))
fig.suptitle("나이대별 관심사", fontsize = 25)
labels = ["액티비티", "맛집탐방", "인생사진", "자연/힐링", "관광명소", "역사/문화"]
colors = ['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
explode = [0.07] * 6

axs[0, 0].pie(values20, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
axs[0, 0].set_title('20대 관심사')


axs[0, 1].pie(values30, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
axs[0, 1].set_title('30대 관심사')
axs[0, 1].legend(fontsize = 7, loc = (1.05, 0.8))

axs[1, 0].pie(values40, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
axs[1, 0].set_title('40대 관심사')

axs[1, 1].pie(values50, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
axs[1, 1].set_title('50대 관심사')

axs[2, 0].pie(values60, labels = labels, autopct = '%.1f%%', startangle = 90, counterclock = False, explode = explode, colors = colors)
axs[2, 0].set_title('60대 이상 관심사')



bar_index = np.arange(6)
w = 0.17
axs[2, 1].set_title('나이대별 관심사 막대그래프')
axs[2, 1].bar(bar_index - w * 2, values20, width = 0.2, label = '20대')
axs[2, 1].bar(bar_index - w, values30, width = 0.2, label = '30대')
axs[2, 1].bar(bar_index , values40, width = 0.2, label = '40대')
axs[2, 1].bar(bar_index + w, values50, width = 0.2, label = '50대')
axs[2, 1].bar(bar_index + w * 2, values60, width = 0.2, label = '60대이상')
axs[2, 1].legend(fontsize = 7, loc = (1.02, 0.8))
axs[2, 1].set_xticks(bar_index, labels, fontsize = 8.2)

plt.show()
