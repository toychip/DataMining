# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
nba = pd.read_csv('nba.csv')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## 임의의 팀 두개를 선택하여라.선택한 팀의 Age, Salary와 Position, Team을 보여라

# %%
chosen = (data['Team'] == 'Utah Jazz') | (data['Team'] == 'Boston Celtics')
exel = nba.loc[chosen, ['Age', 'Salary', 'Team', 'Position']]
exel
# Out:
#       Age      Salary            Team Position
# 0    25.0   7730337.0  Boston Celtics       PG
# 1    25.0   6796117.0  Boston Celtics       SF
# 2    27.0         NaN  Boston Celtics       SG
# 3    22.0   1148640.0  Boston Celtics       SG
# 4    29.0   5000000.0  Boston Celtics       PF
# 5    29.0  12000000.0  Boston Celtics       PF
# 6    21.0   1170960.0  Boston Celtics       PF
# 7    25.0   2165160.0  Boston Celtics        C
# 8    22.0   1824360.0  Boston Celtics       PG
# 9    22.0   3431040.0  Boston Celtics       PG
# 10   24.0   2569260.0  Boston Celtics        C
# 11   27.0   6912869.0  Boston Celtics       PG
# 12   27.0   3425510.0  Boston Celtics       SG
# 13   20.0   1749840.0  Boston Celtics       SG
# 14   26.0   2616975.0  Boston Celtics        C
# 442  28.0   4775000.0       Utah Jazz       PF
# 443  23.0   2658240.0       Utah Jazz       PG
# 444  24.0   9463484.0       Utah Jazz       SG
# 445  20.0   3777720.0       Utah Jazz       PG
# ...

# %% [markdown]
# ## 선택한 두팀의 나이별 연봉을 포지션 별로 구분하여 그림을 그리고 선택한 팀을 분석하여라.

# %%
sns.boxplot(data = exel, x = "Age", y = "Salary", hue = "Position")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Salary'>

# %% [markdown]
# #### 연봉이 가장 높은 선수의 포지션은 SF이고, 나이는 26세이다.
# #### SF에서 26세에서 연봉 차이가 가장 크게 난다.

# %% [markdown]
# ## 나이별 연봉에 대한 요인 분석을 하고 그 해석을 쓰시오 .

# %%
sns.jointplot(data = exel, x = "Age", y = "Salary", kind = "reg")

# %% [markdown]
# #### 나이가 많을수록 연봉이 커진다.
# #### 26세 이상부터 연봉 격차가 커진다.
# #### 26~28세의 선수가 가장 많다

# %% [markdown]
# ## 나이별 포지션 분포를 보이고 해석하시오

# %%
with sns.axes_style('white'):
    g = sns.catplot(data = exel, x = "Age", kind = "count", hue = "Position", aspect = 3.0)

# %% [markdown]
# #### PG는 8명, SF는 4명, SG는 6명, PF는 6명, C는 5명이다.
# #### 같은 나이에 포지션이 가장 많은 나이와 포지션은 26세의 C이다.
# #### 24세가 포지션의 종류가 가장 많다.
