# %% [markdown]
# **아래 패키지 설치**
# - wordcloud
#
# - matplotlib

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2.tar.gz (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 4.8 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wordcloud) (1.23.3)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wordcloud) (3.6.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Using legacy 'setup.py install' for wordcloud, since package 'wheel' is not installed.
# Installing collected packages: wordcloud
#   Running setup.py install for wordcloud ... done
# Successfully installed wordcloud-1.8.2.2
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

text = "파이썬 명지대학교 워드클라우드 ICT 파이썬 명지대학교 정보통신공학과 정보통신 워드클라우드 파이썬 라이브러리 ICT 파이썬 워드클라우드 ICT 명지대학교 워드클라우드  명지대학교  데이터 분석  워드클라우드    "
split_text = text.split()
Counter(split_text)

#wordcloud = WordCloud(font_path='C:\Windows\Fonts\\NanumPen.ttf', background_color='white').generate(text)
wordcloud = WordCloud(font_path='~/Library/Fonts/KoPubWorld Dotum_Pro Medium.otf',background_color='white').generate(text)
# KoPubWorld Dotum_Pro Medium.otf mac쓰는 사람 이대로 맞춰주기
split_text
Counter(split_text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [3], line 10
#       7 Counter(split_text)
#       9 #wordcloud = WordCloud(font_path='C:\Windows\Fonts\\NanumPen.ttf', background_color='white').generate(text)
# ---> 10 wordcloud = WordCloud(font_path='~/Library/Fonts/KoPubWorld Dotum_Pro Medium.otf',background_color='white').generate(text)
#      11 # KoPubWorld Dotum_Pro Medium.otf mac쓰는 사람 이대로 맞춰주기
#      12 split_text
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/wordcloud/wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
#     627     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     637     self
#     638     """
# --> 639     return self.generate_from_text(text)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/wordcloud/wordcloud.py:621, in WordCloud.generate_from_text(self, text)
#     604 """Generate wordcloud from text.
#     605
#     606 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618 self
#     619 """
#     620 words = self.process_text(text)
# --> 621 self.generate_from_frequencies(words)
#     622 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/wordcloud/wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/wordcloud/wordcloud.py:503, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     500 tried_other_orientation = False
#     501 while True:
#     502     # try to find a position
# --> 503     font = ImageFont.truetype(self.font_path, font_size)
#     504     # transpose font optionally
#     505     transposed_font = ImageFont.TransposedFont(
#     506         font, orientation=orientation)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/PIL/ImageFont.py:959, in truetype(font, size, index, encoding, layout_engine)
#     956     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     958 try:
# --> 959     return freetype(font)
#     960 except OSError:
#     961     if not is_path(font):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/PIL/ImageFont.py:956, in truetype.<locals>.freetype(font)
#     955 def freetype(font):
# --> 956     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/PIL/ImageFont.py:247, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     245                 load_from_bytes(f)
#     246             return
# --> 247     self.font = core.getfont(
#     248         font, size, index, encoding, layout_engine=layout_engine
#     249     )
#     250 else:
#     251     load_from_bytes(font)
#
# OSError: cannot open resource

# %%
plt.figure(figsize=(11,11)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show()

# %% [markdown]
# ![](https://matplotlib.org/3.1.1/_images/sphx_glr_interpolation_methods_001.png)
#
#
# 참고 https://matplotlib.org/3.1.1/gallery/images_contours_and_fields/interpolation_methods.html

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt 
 
stopwords = set(STOPWORDS) 
stopwords.add('워드클라우드') 
stopwords.add('ICT') 
stopwords.add('분석') 
 
#wordcloud = WordCloud(font_path='C:\Windows\Fonts\\HMFMMUEX.ttc',stopwords=stopwords,background_color='white').generate(text)
wordcloud = WordCloud(font_path='~/Library/Fonts/KoPubWorld Dotum_Pro Medium.otf',stopwords=stopwords,background_color='white').generate(text)

plt.figure(figsize=(11,11)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show()

# %%
text = open('./worldcloud/constitution.txt').read()
wordcloud = WordCloud().generate(text)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
from PIL import Image

text = open('./worldcloud/alice.txt').read()
alice_mask= np.array(Image.open('./worldcloud/alice.png'))

stopword=set(STOPWORDS)
stopword.add('said')

# %%
plt.figure(figsize=(8,8))
plt.imshow(alice_mask,cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wc = WordCloud(background_color='white',max_words=2000,mask=alice_mask, stopwords= stopword)
wc = wc.generate(text)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import numpy as np
from PIL import Image

#text = open('./data/alice.txt').read()
alice_coloring= np.array(Image.open('./worldcloud/alice_color.png'))

stopword=set(STOPWORDS)
stopword.add('said')

wc = WordCloud(background_color='white',max_words=2000,mask=alice_coloring, stopwords= stopwords)
wc = wc.generate(text)

# %%
from wordcloud import ImageColorGenerator
image_colors=ImageColorGenerator(alice_coloring)
#image_colors.default_color = [0,0,0]
print(image_colors.image.shape)
# Out:
# (800, 600, 4)

# %%
plt.figure(figsize=(8,8))
plt.imshow(alice_coloring,cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func = image_colors), interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 아래 사이트를 참고 하여 작성
# - https://lovit.github.io/nlp/2018/04/17/word_cloud/
# - https://pinkwink.kr/1029
# - https://github.com/amueller/word_cloud
# - https://github.com/lovit/KR-WordRank
