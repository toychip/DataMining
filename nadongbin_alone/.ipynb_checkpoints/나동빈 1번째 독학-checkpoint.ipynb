# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [1, 2, 3]

plt.plot(x, y)
plt.show()
plt.xlabel("X")
plt.ylaber("Y")
plt.savefig("helloMatplot.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [13], line 9
#       7 plt.show()
#       8 plt.xlabel("X")
# ----> 9 plt.ylaber("Y")
#      10 plt.savefig("helloMatplot.png")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylaber'

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0, np.pi * 10, 500)
fig, axes = plt.subplots(2, 1)            # subplots -> 2개의 그래프가 들어가는 Figure 생성
                                          # 지금은 2개의 행에 1개의 열 그래프
axes[0].plot(x, np.sin(x))
axes[1].plot(x, np.cos(x))


# fig.savefig("sin&cos.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-9, 10)
y = x ** 2

# 라인 스타일로는 '-', ':', 'ㅡ.', '--'등이 사용 가능

plt.plot(
    x, y, linestyle = ":", marker = "*",
    markersize=8, markerfacecolor = "blue", markeredgecolor = "red"
)
                            #   marker는 각 점을 해당하는 것.
                            #   linestyle = ":" 이것으로 하면 실선 스타일로 선을 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-9, 10)
y1 = x ** 2
y2 = -x
plt.plot(x, y1, linestyle="-.", marker = "*", color = "red", label = "y= x + x")
plt.plot(x, y2, linestyle=":", marker = "o", color = "blue", label = "y= -x")
plt.xlabel("X")   # x축을 x로
plt.ylabel("Y")   # Y축을 y로

plt.legend(       # 위에 박스처럼 무언가 값을 보여줄 때
shadow = True,    # shadow를 줘서 음영을 지게 함
borderpad         # 박스 형태
)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
                                            # 막대 그래프 그리기
x = np.arange(-9, 10)
plt.bar(x, x**2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(10)
y = np.random.rand(10)
z = np.random.rand(10)
data = [x, y, z]
x_array = np.arange(10)
for i in range(0, 3):
    plt.bar(
    x_array,
    data[i],
    bottom = np.sum(data[:i], axis = 0)
    )
plt.show()
